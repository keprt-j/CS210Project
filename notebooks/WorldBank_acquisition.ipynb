# %% [markdown]
# # World Bank Data Acquisition
#
# This notebook acquires economic and demographic data from the World Bank API for UN member countries and stores it in a SQLite database.

# %% [markdown]
# ## Step 1: Import Required Libraries

# %%
import requests
import sqlite3
import pathlib
from concurrent.futures import ThreadPoolExecutor, as_completed
from typing import Optional, Tuple
import pycountry
import os
import pathlib

# %% [markdown]
# ## Step 2: Define Core Functions

# %%
def get_wb_country_data(country_code, indicator_code, format='json', year1=None, year2=None, numResults=50):
    url = 'http://api.worldbank.org/v2/country/'+country_code+'/indicator/'+indicator_code+'?'+'format='+format
    if year1 and year2:
        url += '&date='+str(year1)+':'+str(year2)
    if numResults:
        url += '&per_page='+str(numResults)
    response = requests.get(url)
    return response.json()

def get_db_connection(db_path: pathlib.Path) -> sqlite3.Connection:
    db_path = pathlib.Path(db_path)
    db_path.parent.mkdir(parents=True, exist_ok=True)
    conn = sqlite3.connect(db_path)
    return conn

def create_tables(conn: sqlite3.Connection, schema: list) -> None:
    cursor = conn.cursor()
    for table in schema:
        cursor.execute(table)
    conn.commit()

def insert_data(conn: sqlite3.Connection, data: list) -> None:
    cursor = conn.cursor()
    cursor.executemany(f"INSERT INTO country_data(country_code, gdp_value_US, poverty_rate, population) VALUES (?, ?, ?, ?)", data)
    conn.commit()

def get_country_info(conn: sqlite3.Connection):
    cursor = conn.cursor()
    cursor.execute("SELECT * FROM country_data")
    return cursor.fetchall()

# %% [markdown]
# ## Step 3: Define UN Member Countries and Utility Functions

# %%
UN_MEMBERS = {
    'AFG', 'ALB', 'DZA', 'AND', 'AGO', 'ATG', 'ARG', 'ARM', 'AUS', 'AUT',
    'AZE', 'BHS', 'BHR', 'BGD', 'BRB', 'BLR', 'BEL', 'BLZ', 'BEN', 'BTN',
    'BOL', 'BIH', 'BWA', 'BRA', 'BRN', 'BGR', 'BFA', 'BDI', 'CPV', 'KHM',
    'CMR', 'CAN', 'CAF', 'TCD', 'CHL', 'CHN', 'COL', 'COM', 'COG', 'COD',
    'CRI', 'CIV', 'HRV', 'CUB', 'CYP', 'CZE', 'DNK', 'DJI', 'DMA', 'DOM',
    'ECU', 'EGY', 'SLV', 'GNQ', 'ERI', 'EST', 'SWZ', 'ETH', 'FJI', 'FIN',
    'FRA', 'GAB', 'GMB', 'GEO', 'DEU', 'GHA', 'GRC', 'GRD', 'GTM', 'GIN',
    'GNB', 'GUY', 'HTI', 'HND', 'HUN', 'ISL', 'IND', 'IDN', 'IRN', 'IRQ',
    'IRL', 'ISR', 'ITA', 'JAM', 'JPN', 'JOR', 'KAZ', 'KEN', 'KIR', 'PRK',
    'KOR', 'KWT', 'KGZ', 'LAO', 'LVA', 'LBN', 'LSO', 'LBR', 'LBY', 'LIE',
    'LTU', 'LUX', 'MDG', 'MWI', 'MYS', 'MDV', 'MLI', 'MLT', 'MHL', 'MRT',
    'MUS', 'MEX', 'FSM', 'MDA', 'MCO', 'MNG', 'MNE', 'MAR', 'MOZ', 'MMR',
    'NAM', 'NRU', 'NPL', 'NLD', 'NZL', 'NIC', 'NER', 'NGA', 'MKD', 'NOR',
    'OMN', 'PAK', 'PLW', 'PAN', 'PNG', 'PRY', 'PER', 'PHL', 'POL', 'PRT',
    'QAT', 'ROU', 'RUS', 'RWA', 'KNA', 'LCA', 'VCT', 'WSM', 'SMR', 'STP',
    'SAU', 'SEN', 'SRB', 'SYC', 'SLE', 'SGP', 'SVK', 'SVN', 'SLB', 'SOM',
    'ZAF', 'SSD', 'ESP', 'LKA', 'SDN', 'SUR', 'SWE', 'CHE', 'SYR', 'TJK',
    'TZA', 'THA', 'TLS', 'TGO', 'TON', 'TTO', 'TUN', 'TUR', 'TKM', 'TUV',
    'UGA', 'UKR', 'ARE', 'GBR', 'USA', 'URY', 'UZB', 'VUT', 'VAT', 'VEN',
    'VNM', 'YEM', 'ZMB', 'ZWE'
}

def average_value(json_data: list) -> float:
    sum = 0
    for i in range(len(json_data[1])):
        value = json_data[1][i]['value']
        sum += value if value is not None else 0
    avg = sum/len(json_data[1])
    return avg

# %% [markdown]
# ## Step 4: Define Data Fetching and Processing Functions

# %%
def fetch_country_indicator(country: str, indicator: str):
    try:
        json_data = get_wb_country_data(country, indicator, format='json', year1=2020, year2=2024, numResults=10)
        return average_value(json_data)
    except Exception as e:
        print(f'Error fetching {indicator} for {country}')
        return None

def country_tuple(country, max_workers = 3):
    if country not in UN_MEMBERS:
        print(f'Skipped: {country} (not UN member)')

    print('Processing: ' + country)

    with ThreadPoolExecutor(max_workers) as executor:
        future_gdp = executor.submit(fetch_country_indicator, country, "NY.GDP.MKTP.CD")
        future_pov = executor.submit(fetch_country_indicator, country, "SI.POV.DDAY")
        future_pop = executor.submit(fetch_country_indicator, country, "SP.POP.TOTL")
            
        avg_GDP = future_gdp.result()
        avg_pov = future_pov.result()
        avg_pop = future_pop.result()    
    
    return (country, avg_GDP, avg_pov, avg_pop)

def bulk_insertion_concurrent(codes: list, conn: sqlite3.Connection, max_workers: int = 10):
    un_member_codes = list(UN_MEMBERS)

    results = []

    with ThreadPoolExecutor(max_workers) as executor:
        future_country = {executor.submit(country_tuple, country): country for country in un_member_codes}

        for future in as_completed(future_country):
            try:
                country = future_country[future]
                result = future.result()
                if result is not None:
                    results.append(result)
            except Exception as e:
                print(f'Error processing {country}: {e}')
    
    if results:
        print('Full insertion beginning.')
        insert_data(conn, results)
        print('Completed Insertion.')
    else:
        print('No data to insert.')

# %% [markdown]
# ## Step 5: Set Up Project Paths and Database Location

# %%
project_root = next((p for p in [pathlib.Path.cwd()] + list(pathlib.Path.cwd().parents) 
                     if (p / 'notebooks' / 'WorldBank_acquisition.ipynb').exists()),
                    pathlib.Path.cwd())
os.chdir(project_root)

DATABASE_PATH = str(project_root / "data" / "database" / "tb_data.db")
RAW_DATA_DIR = project_root / "data" / "raw"

print(f"✓ Project: {project_root}")
print(f"✓ Database: {DATABASE_PATH}")
# Out:
# ✓ Project: /Users/prathamwankhede/Documents/CS210Project
# ✓ Database: /Users/prathamwankhede/Documents/CS210Project/data/database/tb_data.db

# %% [markdown]
# ## Step 6: Define Database Schema

# %%
schema = [
    """CREATE TABLE IF NOT EXISTS country_data (
        id INTEGER PRIMARY KEY AUTOINCREMENT, 
        country_code TEXT, 
        gdp_value_US REAL,
        poverty_rate REAL,
        population REAL,
        FOREIGN KEY (country_code) REFERENCES country_metadata(country_code)
        )
    """
]

# %% [markdown]
# ## Step 7: Initialize Database

# %%
conn = get_db_connection(DATABASE_PATH)
cursor = conn.cursor()
cursor.execute("DROP TABLE IF EXISTS country_data")
create_tables(conn, schema=schema)
country_codes = list(pycountry.countries)

# %% [markdown]
# ## Step 8: Fetch and Insert Data
#
# **This is the main data acquisition step.**

# %%
bulk_insertion_concurrent(country_codes, conn)
# Out:
# Processing: BHS
# Processing: KIR
# Processing: CMR
# Processing: GUY
# Processing: ZMB
# Processing: DJI
# Processing: MYS
# Processing: GBR
# Processing: JOR
# Processing: SWZ
# Processing: TCD
# Processing: SLE
# Processing: COM
# Processing: VNM
# Processing: HUN
# Processing: LUX
# Processing: KEN
# Processing: AND
# Processing: KWT
# Processing: MHL
# Processing: IRL
# Processing: SWE
# Processing: NLD
# Processing: BHR
# Processing: MNG
# Processing: BFA
# Processing: ALB
# Processing: GNB
# Processing: KOR
# Processing: GNQ
# Processing: MDV
# Processing: OMN
# Processing: SAU
# Processing: UZB
# Processing: MKD
# Processing: GHA
# Processing: LTU
# Processing: IDN
# Processing: PAN
# Processing: FSM
# Processing: ARE
# Processing: SYC
# Processing: BDI
# Processing: QAT
# Processing: LCA
# Processing: MRT
# Processing: ISR
# Processing: BGD
# Processing: HTI
# Processing: MDA
# Processing: GRC
# Processing: MWI
# Processing: AZE
# Processing: SSD
# Processing: BIH
# Processing: STP
# Processing: VEN
# Processing: COD
# Processing: DMA
# Processing: TON
# Processing: BEL
# Processing: URY
# Processing: CAF
# Processing: KGZ
# Processing: PLW
# Processing: SGP
# Processing: KAZ
# Processing: LKA
# Processing: ITA
# Processing: IRN
# Processing: ESP
# Processing: TKM
# Processing: ARM
# Processing: SYR
# Processing: AFG
# Processing: NER
# Processing: GIN
# Processing: HND
# Processing: UGA
# Processing: UKR
# Processing: EST
# Processing: SMR
# Processing: MAR
# Processing: COL
# Processing: RUS
# Processing: MCO
# Processing: PRK
# Processing: ECU
# Processing: WSM
# Processing: LBY
# Processing: TUR
# Processing: DEU
# Processing: SEN
# Processing: ETH
# Processing: FRA
# Processing: LBR
# Processing: NZL
# Processing: FJI
# Processing: BRN
# Processing: SRB
# Processing: CUB
# Processing: BRB
# Processing: TUV
# Processing: PAK
# Processing: GAB
# Processing: DNK
# Processing: CHN
# Processing: GMB
# Processing: CANProcessing: YEM
#
# Processing: BLR
# Processing: EGY
# Processing: NAM
# Processing: DZA
# Processing: ROU
# Processing: CHL
# Processing: CYP
# Processing: JPN
# Processing: LVA
# Processing: AUT
# Processing: LIE
# Processing: BLZ
# Processing: LBN
# Processing: MDG
# Processing: ZWE
# Processing: VAT
# Processing: ATG
# Processing: SDN
# Processing: KNA
# Processing: PRY
# Processing: BOL
# Processing: SOM
# Processing: PHL
# Error fetching SI.POV.DDAY for VAT
# Error fetching SP.POP.TOTL for VAT
# Processing: MOZ
# Processing: HRV
# Processing: BGR
# Processing: MEX
# Processing: TZA
# Error fetching NY.GDP.MKTP.CD for VAT
# Processing: NIC
# Processing: CHE
# Processing: LAO
# Processing: RWA
# Processing: ISL
# Processing: IND
# Processing: THA
# Processing: TGO
# Processing: PER
# Processing: GRD
# Processing: SLB
# Processing: NGA
# Processing: TLS
# Processing: FIN
# Processing: MMR
# Processing: PNG
# Processing: TTO
# Processing: USA
# Processing: SVK
# Processing: AGO
# Processing: PRT
# Processing: BWA
# Processing: DOM
# Processing: CZE
# Processing: ARG
# Processing: CIV
# Processing: GTM
# Processing: NRU
# Processing: MUS
# Processing: TJK
# Processing: COG
# Processing: TUN
# Processing: VCT
# Processing: MLTProcessing: SVN
#
# Processing: CPV
# Processing: MNE
# Processing: SLV
# Processing: POL
# Processing: VUT
# Processing: ERI
# Processing: JAM
# Processing: ZAF
# Processing: KHMProcessing: NOR
#
# Processing: IRQ
# Processing: GEO
# Processing: AUS
# Processing: SUR
# Processing: BTN
# Processing: CRI
# Processing: NPL
# Processing: LSO
# Processing: BEN
# Processing: BRA
# Processing: MLI
# Full insertion beginning.
# Completed Insertion.

# %% [markdown]
# ## Step 9: Verify Data Insertion

# %%
get_country_info(conn)
# Out:
# [(1, 'JOR', 48640442507.042274, 0.0, 11235987.2),
#  (2, 'MYS', 388104813734.0072, 0.0, 34710284.2),
#  (3, 'CMR', 46147712052.82514, 5.34, 27651103.6),
#  (4, 'KIR', 274534325.7314058, 0.0, 130398.6),
#  (5, 'GUY', 13997082123.453236, 0.0, 820408.0),
#  (6, 'DJI', 3620660251.630366, 0.0, 1137039.6),
#  (7, 'ZMB', 24660339152.282463, 14.34, 20170972.2),
#  (8, 'SWZ', 4628709844.658633, 0.0, 1218313.4),
#  (9, 'GBR', 3193567997243.018, 0.2, 67810000.0),
#  (10, 'BHS', 13480220000.0, 0.0, 398099.4),
#  (11, 'COM', 1356061722.4578419, 0.0, 834308.0),
#  (12, 'TCD', 17873348098.793243, 7.9, 18625291.0),
#  (13, 'SLE', 6990272862.107933, 0.0, 8277300.2),
#  (14, 'LUX', 84326114459.20609, 0.06000000000000001, 653546.6),
#  (15, 'VNM', 407356326732.5698, 0.5800000000000001, 99606964.4),
#  (16, 'HUN', 191243033184.5868, 0.0, 9612185.0),
#  (17, 'AND', 3484234594.81185, 0.0, 79648.6),
#  (18, 'KEN', 111469484695.5792, 27.54, 54292181.6),
#  (19, 'KWT', 153701973802.5892, 0.0, 4635611.2),
#  (20, 'MHL', 258751568.84596044, 0.0, 40105.0),
#  (21, 'IRL', 529043330000.0244, 0.12000000000000002, 5210205.0),
#  (22, 'SWE', 591567599317.1772, 0.64, 10472507.0),
#  (23, 'NLD', 1083095802682.776, 0.02, 17709376.0),
#  (24, 'BFA', 19963515652.31318, 8.42, 22511505.6),
#  (25, 'BHR', 43412999999.99999, 0.0, 1533398.2),
#  (26, 'ALB', 20603124966.68832, 0.06, 2777558.6),
#  (27, 'MNG', 17931414415.37296, 0.08, 3430125.2),
#  (28, 'KOR', 1369890860957.658, 0.04, 51748406.2),
#  (29, 'GNB', 1919801971.2229557, 7.9799999999999995, 2106463.2),
#  (30, 'OMN', 97184915474.64241, 0.0, 4816790.8),
#  (31, 'GNQ', 12180133147.3795, 1.7600000000000002, 1803772.8),
#  (32, 'MDV', 5741644143.649804, 0.0, 519234.2),
#  (33, 'SAU', 1089160373333.3334, 0.0, 32703025.6),
#  (34, 'MKD', 14548519614.199759, 0.0, 1828989.0),
#  (35, 'UZB', 90297284940.83084, 3.12, 34956637.8),
#  (36, 'LTU', 72028467394.311, 0.54, 2842005.6),
#  (37, 'GHA', 77362777513.52176, 0.0, 33154190.8),
#  (38, 'IDN', 1266427023383.9897, 7.6800000000000015, 279016289.2),
#  (39, 'FSM', 419160683.04956883, 0.0, 112088.8),
#  (40, 'SYC', 1848538290.446736, 0.0, 111745.0),
#  (41, 'PAN', 74062186520.0, 2.0200000000000005, 4402755.0),
#  (42, 'ARE', 463718601012.9342, 0.0, 10082379.8),
#  (43, 'QAT', 198167695000.0, 0.0, 2694049.0),
#  (44, 'LCA', 2137680740.740738, 0.0, 178916.4),
#  (45, 'BDI', 2711194429.081678, 14.84, 13328170.0),
#  (46, 'MRT', 9691939327.04048, 0.0, 4880495.6),
#  (47, 'BGD', 427583507399.3939, 1.1800000000000002, 169674225.8),
#  (48, 'ISR', 495673094183.2368, 0.27999999999999997, 9593480.0),
#  (49, 'AZE', 64614047058.82353, 0.0, 10145887.0),
#  (50, 'MDA', 14932040124.424139, 0.06000000000000001, 2521330.2),
#  (51, 'HTI', 20142786020.92192, 0.0, 11506399.0),
#  (52, 'SSD', 0.0, 0.0, 11202441.2),
#  (53, 'MWI', 12059515780.835258, 0.0, 20581928.4),
#  (54, 'BIH', 24873833606.826942, 0.0, 3219676.8),
#  (55, 'GRC', 225838099686.8022, 0.6, 10499816.2),
#  (56, 'VEN', 0.0, 0.0, 28320263.4),
#  (57, 'STP', 595938349.3830261, 0.0, 226421.6),
#  (58, 'COD', 61520620943.56162, 17.06, 102520378.8),
#  (59, 'DMA', 612622222.2222221, 0.0, 66863.2),
#  (60, 'TON', 408399893.8196686, 0.08, 105001.6),
#  (61, 'BEL', 606210185333.6106, 0.04, 11693855.2),
#  (62, 'CAF', 2506574906.837536, 14.319999999999999, 5143975.6),
#  (63, 'URY', 68769146466.8086, 0.22000000000000003, 3392249.0),
#  (64, 'PLW', 206436780.0, 0.0, 17751.2),
#  (65, 'SGP', 469520248382.2909, 0.0, 5746180.6),
#  (66, 'KGZ', 12462727121.440845, 4.44, 6975480.8),
#  (67, 'LKA', 85942924374.7725, 0.0, 22041800.0),
#  (68, 'KAZ', 228787437887.6242, 0.0, 20036600.8),
#  (69, 'ITA', 2173627237130.1382, 0.6799999999999999, 59113037.8),
#  (70, 'ESP', 1508072719972.9958, 0.6799999999999999, 47948878.8),
#  (71, 'IRN', 376303398068.7616, 2.7199999999999998, 89575924.4),
#  (72, 'ARM', 19181289861.449722, 1.48, 2978160.0),
#  (73, 'NER', 16065986902.94132, 12.1, 25344801.0),
#  (74, 'AFG', 13173080600.44614, 0.0, 40750097.2),
#  (75, 'TKM', 55933235490.723366, 0.0, 7226216.8),
#  (76, 'SYR', 14003444948.727661, 3.3, 22681564.8),
#  (77, 'GIN', 19762037091.497658, 0.0, 14059417.2),
#  (78, 'HND', 30874395435.838318, 6.540000000000001, 10468788.6),
#  (79, 'UKR', 178067176781.14923, 0.0, 41124095.4),
#  (80, 'EST', 38291511022.37226, 0.3, 1350313.2),
#  (81, 'UGA', 45223264074.724625, 0.0, 47270498.8),
#  (82, 'COL', 343867869535.2826, 8.34, 51752725.8),
#  (83, 'MAR', 138635145915.6028, 0.0, 37332278.4),
#  (84, 'SMR', 1046362214.0196941, 0.0, 34122.8),
#  (85, 'MCO', 6829952011.875656, 0.0, 38619.0),
#  (86, 'RUS', 1971843253394.8242, 0.1, 144317764.8),
#  (87, 'PRK', 0.0, 0.0, 26322943.6),
#  (88, 'ECU', 113000159940.0, 6.0200000000000005, 17833595.4),
#  (89, 'TUR', 977765983105.8656, 0.5, 84671307.4),
#  (90, 'WSM', 910396378.0212647, 0.0, 215133.2),
#  (91, 'ETH', 69138465788.87161, 7.720000000000001, 125438401.0),
#  (92, 'LBY', 43410264176.81622, 0.0, 7218212.2),
#  (93, 'SEN', 28559643022.202618, 3.5799999999999996, 17648149.2),
#  (94, 'DEU', 4327533916027.8345, 0.04, 83513561.4),
#  (95, 'NZL', 246389676628.242, 0.0, 5180420.0),
#  (96, 'FRA', 2924914528479.504, 0.08, 68062624.4),
#  (97, 'LBR', 3966044560.0, 0.0, 5377585.6),
#  (98, 'SRB', 71851526705.89508, 1.1400000000000001, 6721657.2),
#  (99, 'FJI', 4997922408.936422, 0.0, 920805.0),
#  (100, 'BRN', 14650410358.90096, 0.0, 455233.0),
#  (101, 'BRB', 6117324640.0, 0.0, 282193.2),
#  (102, 'CUB', 21470360000.0, 0.0, 11071611.2),
#  (103, 'TUV', 46657858.740255296, 0.0, 10009.4),
#  (104, 'GAB', 19230118459.1201, 0.0, 2430749.8),
#  (105, 'GMB', 2186939047.9385324, 4.4, 2637209.2),
#  (106, 'PAK', 346957988087.8828, 0.0, 243390774.6),
#  (107, 'DNK', 400500819011.3712, 0.2, 5903023.6),
#  (108, 'YEM', 0.0, 0.0, 38294386.4),
#  (109, 'CAN', 2056613491918.482, 0.08, 39315303.8),
#  (110, 'CHN', 17705807546665.938, 0.0, 1411064000.0),
#  (111, 'NAM', 12267261912.98904, 0.0, 2884439.6),
#  (112, 'BLR', 70652245248.71082, 0.0, 9244523.6),
#  (113, 'EGY', 414044662706.8234, 0.27999999999999997, 112792882.4),
#  (114, 'ROU', 313701955023.65283, 1.3199999999999998, 19112926.0),
#  (115, 'CHL', 307275894696.1708, 0.44000000000000006, 19560720.0),
#  (116, 'CYP', 31416651095.06056, 0.0, 1330836.8),
#  (117, 'JPN', 4519011510217.334, 0.24, 125111920.6),
#  (118, 'LVA', 39134178677.315384, 0.36, 1880841.6),
#  (119, 'BLZ', 2778546665.782158, 0.0, 403413.8),
#  (120, 'DZA', 217597806536.5126, 0.0, 45451821.2),
#  (121, 'LIE', 5996875559.191119, 0.0, 39524.6),
#  (122, 'LBN', 19183022423.27632, 1.1800000000000002, 5748892.8),
#  (123, 'ZWE', 33263560605.658203, 0.0, 16073669.8),
#  (124, 'MDG', 15204507343.889038, 13.84, 30448557.6),
#  (125, 'AUT', 483993187898.7212, 0.45999999999999996, 9044951.0),
#  (126, 'ATG', 1822185925.9259257, 0.0, 92824.6),
#  (127, 'SDN', 40547815947.71692, 0.0, 48946251.0),
#  (128, 'KNA', 969233333.3333327, 0.0, 46788.6),
#  (129, 'VAT', None, None, None),
#  (130, 'BOL', 43169586625.1809, 2.6799999999999997, 12097657.4),
#  (131, 'PHL', 411773002386.2234, 2.6799999999999997, 113976284.2),
#  (132, 'PRY', 40982432087.84515, 2.44, 6764336.8),
#  (133, 'SOM', 10278438115.999893, 0.0, 17818457.0),
#  (134, 'MOZ', 18531575111.606518, 16.28, 32682932.0),
#  (135, 'BGR', 92016561047.1991, 0.8, 6482811.2),
#  (136, 'HRV', 75017755979.35799, 0.27999999999999997, 3874962.8),
#  (137, 'MEX', 1510124175608.3699, 1.3199999999999998, 128732217.0),
#  (138, 'TZA', 74067321830.62363, 0.0, 64738558.8),
#  (139, 'NIC', 16013968109.60642, 0.0, 6736083.0),
#  (140, 'RWA', 12630539977.50672, 7.720000000000001, 13656633.0),
#  (141, 'CHE', 843361336728.892, 0.06000000000000001, 8808399.2),
#  (142, 'ISL', 28202355507.276073, 0.0, 383789.0),
#  (143, 'PER', 245996944284.31284, 6.26, 33506672.8),
#  (144, 'IND', 3347880950838.948, 1.06, 1426250038.0),
#  (145, 'LAO', 17124765567.453222, 0.0, 7558709.2),
#  (146, 'THA', 508923762845.292, 0.02, 71694918.2),
#  (147, 'TGO', 8601799583.995493, 6.88, 9091482.0),
#  (148, 'GRD', 1222672961.4814801, 0.0, 116846.0),
#  (149, 'NGA', 380408394075.443, 8.36, 223247757.2),
#  (150, 'SLB', 1609393078.252268, 0.0, 781471.6),
#  (151, 'TLS', 2591457027.773232, 0.0, 1366082.2),
#  (152, 'FIN', 287852573139.161, 0.06000000000000001, 5569558.2),
#  (153, 'MMR', 69688369269.48648, 0.0, 53758860.0),
#  (154, 'PNG', 28993178882.897602, 0.0, 10199589.6),
#  (155, 'AGO', 76935708496.66542, 0.0, 35650869.0),
#  (156, 'SVK', 123970088525.01501, 0.36, 5437327.0),
#  (157, 'TTO', 25119462175.03348, 0.0, 1367186.2),
#  (158, 'PRT', 268190721519.11157, 0.3, 10474610.8),
#  (159, 'BWA', 18568725258.610058, 0.0, 2441722.0),
#  (160, 'USA', 25589553600000.0, 0.6799999999999999, 334922404.0),
#  (161, 'DOM', 106322792770.12976, 1.1400000000000001, 11224266.4),
#  (162, 'GTM', 95476884926.03601, 1.94, 17867009.8),
#  (163, 'CIV', 74580356905.20395, 4.18, 30410014.2),
#  (164, 'NRU', 152808287.59097522, 0.0, 11795.0),
#  (165, 'CZE', 306431369504.0179, 0.02, 10724390.8),
#  (166, 'TJK', 10846807787.910051, 6.279999999999999, 10175833.2),
#  (167, 'MUS', 12970794848.25868, 0.0, 1263084.2),
#  (168, 'ARG', 556887326807.7878, 1.4200000000000002, 45429342.0),
#  (169, 'VCT', 994375555.5555569, 0.0, 102070.4),
#  (170, 'COG', 14630489885.317822, 0.0, 6039184.8),
#  (171, 'TUN', 47224010995.47452, 0.13999999999999999, 12123910.6),
#  (172, 'MLT', 20381075209.268776, 0.12000000000000002, 538369.2),
#  (173, 'SLV', 31010670000.0, 2.98, 6283718.2),
#  (174, 'SVN', 63295044137.82637, 0.0, 2113871.8),
#  (175, 'CPV', 2285442804.5842104, 0.0, 519655.4),
#  (176, 'MNE', 6492271090.589454, 0.9400000000000001, 624518.8),
#  (177, 'POL', 743567887898.75, 0.16, 36912223.2),
#  (178, 'VUT', 1042000538.1963117, 0.0, 313191.6),
#  (179, 'ERI', 0.0, 0.0, 3411378.8),
#  (180, 'ZAF', 389348306734.6588, 0.0, 62332593.0),
#  (181, 'NOR', 486795237189.1288, 0.2, 5467357.6),
#  (182, 'IRQ', 245297056925.3684, 0.1, 44074886.2),
#  (183, 'KHM', 40058212895.8221, 0.0, 17192836.8),
#  (184, 'SUR', 3596149599.4521513, 0.44000000000000006, 623338.8),
#  (185, 'JAM', 16984282477.242237, 0.27999999999999997, 2837305.2),
#  (186, 'AUS', 1611251739977.2039, 0.2, 26241329.0),
#  (187, 'CRI', 75689665427.70615, 2.0, 5082301.6),
#  (188, 'BTN', 2228777784.649392, 0.0, 780854.2),
#  (189, 'LSO', 2242063010.3590302, 0.0, 2286454.8),
#  (190, 'NPL', 39100696182.78767, 0.48, 29500537.6),
#  (191, 'MLI', 23456294169.48768, 7.220000000000001, 23084565.6),
#  (192, 'BRA', 1893844483762.386, 3.8, 210331370.6),
#  (193, 'BEN', 18391141045.637657, 5.4399999999999995, 13763369.0),
#  (194, 'GEO', 24880505723.06374, 8.1, 3706632.2)]
